# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

def create_patch2(vertices, color='orange', label=None):
    """Creates a polygon patch from the given vertices(advice given bt teacher)."""
    return patches.Polygon(vertices, closed=True, fill=True, edgecolor='none', color='orange', label=label)

def plot_polygons2(vertices_list2, labels2=None, figsize=(13, 6)):
    """Generates a plot with polygons created from a list of vertices."""

    fig, ax = plt.subplots(figsize=figsize)

    for i, vertices in enumerate(vertices_list2):
        label = labels2[i] if labels2 else None
        polygon2 = create_patch2(vertices, label=label)
        ax.add_patch(polygon2)

    ax.set_xlim(0, 10)  # Adjusted for lake's shifted coordinates
    ax.set_ylim(0, 6)

    if labels2:

        plt.legend(loc='upper left')

    plt.show()


# Define the vertices of the polygons
river_vertices1 = [(1.24, 2.2), (1.8568, 2.19), (1.8568, 2.22),(1.24, 2.22) ]
lake_vertices11 = [(1.8568,2.2),(1.8,2.2), (1.8, 4.18), (1.8, 4.18)]
lake_vertices21 = [(1.832,2.2) , (2.7541, 2.0983), (2.7541,2.1648),  (1.85668, 2.24)]
lake_vertices31 = [(2.775, 2.0983), (3.0935, 2.25), (3.0935, 2.34),(2.752,2.1648) ]  # River
lake_vertices41 = [(3.0935, 2.25), (3.5,1.869), (3.5,1.987),(3.0935, 2.34)]  # River
lake_vertices51=[(3.5,1.869),  (4,1.934), (3.965,2.055),  (3.5,1.987)]
lake_vertices61=[(3.95,1.934),(3.748,3.82), (3.803,3.9258),(3.965,2.055)]
lake_vertices71 = [(4,1.934),(4.95,2.401) ,(4.985,2.536), (3.965,2.055)]  # River
lake_vertices81=[(4.95,2.401), (5.88,2.441), (5.88,2.6074),(4.985,2.536) ]
lake_vertices91=[(5.88,2.441),(6.56,2.7), (6.56,2.895),(5.88,2.6074)]
lake_vertices101=[(6.56,2.7), (8.06,3.788), (8.06,4),(6.56,2.895)]
lake_vertices111=[(8.06,3.788) , (8.69,3.4), (8.69,3.65),(8.06,4)]
lake_vertices112=[(8.69,3.4), (9.05, 3.6), (8.91,3.8),(8.69,3.65)]
lake_vertices113=[(9.05, 3.6), (9.14, 4.57), (9,4.63),(8.91,3.8)]
lake_vertices114=[(9.14, 4.57), (9.265,4.685),(9.2, 4.91),(9,4.63)]



vertices_list2 = [river_vertices1 ,lake_vertices11,lake_vertices21,lake_vertices31,
                 lake_vertices41 ,lake_vertices51, lake_vertices61, lake_vertices71,
                 lake_vertices81,lake_vertices91, lake_vertices101, lake_vertices111,
                 lake_vertices112, lake_vertices113, lake_vertices114
                 ]
labels2= ['Retreat',None, None, None,None,None,None,None,None,None,None,None,None,
           None, None]

plot_polygons2(vertices_list2, labels2=labels2)
# Out:
# <ipython-input-11-bbefc3138ec8>:6: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   return patches.Polygon(vertices, closed=True, fill=True, edgecolor='none', color='orange', label=label)

# %%
from altair import LabelOverlap
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import seaborn as sns

def create_patch(vertices, color='orange', label=None):
    """Creates a polygon patch from the given vertices."""
    return patches.Polygon(vertices, closed=True, fill=True, edgecolor='none', color=color, label=label)

def plot_polygons_with_cities(vertices_list2, city_names2, figsize=(12.8, 9.6), labels2=None, additional_texts=None):
    """Generates a plot with polygons created from a list of vertices, and displays city labels."""
    fig, ax = plt.subplots(figsize=figsize)

    for vertices, city_name, label in zip(vertices_list2, city_names2, labels2):
        polygon = create_patch(vertices, label=label)
        ax.add_patch(polygon)

        # Calculate the centroid of the polygon
        centroid_x = sum(v[0] for v in vertices) / len(vertices)
        centroid_y = sum(v[1] for v in vertices) / len(vertices)

        ax.annotate(text=city_name,
            xy=(centroid_x, centroid_y),
            xytext=(10, -10), textcoords='offset points', ha='center', va='center', fontsize=8, color='black')

    if additional_texts is not None:
        for text, x, y in additional_texts:
            ax.annotate(text, xy=(x, y), xytext=(10, -10), textcoords='offset points',
                        ha='center', va='center', fontsize=8, color='black')
    ax.set_xlim(0, 10)  # Adjusted for lake's shifted coordinates
    ax.set_ylim(0, 6)

    if labels2:
        plt.legend(loc='upper left')

    plt.show()

additional_texts = [('Smarhon', 2.4, 2.4), ('Mozhaysk', 8.06,4), ('Bobr', 4,2.1), ('´Polostk', 3.853,4)]

city_names2 = [' ',' ', '','Maladzynechna ','Minsk','Studianka','','Monilev', 'Orsha', 'Smolensk', 'Vyazma', 'Mozhaysk','Maloyaroslavets', 'Tarutino', '' ]
plot_polygons_with_cities(vertices_list2, city_names2, figsize=(12.8, 9.6), labels2=labels2, additional_texts=additional_texts)
# Out:
# <ipython-input-12-1d7fa12d20c2>:9: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   return patches.Polygon(vertices, closed=True, fill=True, edgecolor='none', color=color, label=label)

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

def crear_figuras(vertices, color='orange', label=None):
    """Creates a polygon patch from the given vertices."""
    return patches.Polygon(vertices, closed=True, fill=True, edgecolor='none', color=color, label=label)

def plot_of_polygons(vertices_list, labels=None, figsize=(12.8, 9.6)):
    """Generates a plot with polygons created from a list of vertices."""

    fig, ax = plt.subplots(figsize=figsize)

    for i, vertices in enumerate(vertices_list):
        label = labels[i] if labels else None
        polygon = crear_figuras(vertices, label=label)
        ax.add_patch(polygon)

    ax.set_xlim(0, 10)  # Adjusted for lake's shifted coordinates
    ax.set_ylim(0, 6)

    if labels:
        plt.legend(loc='upper left')

    plt.show()


# Define the vertices of the polygons
river_vertices = [(1.2, 2.23), (1.75, 2.41), (1.75, 3.4), (1, 3.2)]
lake_vertices1 = [(1.75, 2.41), (1.8, 2.41), (1.8, 4.18), (1.7, 4.18)]
lake_vertices2 = [(1.8, 2.41), (2.51, 2.24), (2.51, 3.08), (1.8, 3.3)]
lake_vertices3 = [(2.348, 3.11), (2.46, 3.065), (2.9335, 3.791), (2.8765, 3.9875)]  # River
lake_vertices4 = [(2.9335, 3.791), (3.748,3.82), (3.803,3.9258),(2.8765, 3.9875)]  # River
lake_vertices5=[(2.51,2.24), (4.656,3.056), (4.656,3.615), (2.51,3.08)]
lake_vertices6=[(4.656,3.056),(5.8,2.667), (5.775,3.115),(4.656,3.615)]
lake_vertices7 = [(5.8,2.667),(6.65,3.23) ,(6.609,3.621), (5.775,3.115)]  # River
lake_vertices8=[(6.65,3.23), (7.714,4.252), (7.657,4.576), (6.609,3.621)]
lake_vertices9=[(7.714,4.252),(8.454,4.1021), (8.447,4.348),(7.657,4.576)]
lake_vertices10=[(8.454,4.1021), (9.19,4.945), (9.128,5.146),(8.447,4.348)]




vertices_list = [river_vertices, lake_vertices1, lake_vertices2, lake_vertices3,
                 lake_vertices4,lake_vertices5, lake_vertices6, lake_vertices7,
                 lake_vertices8,lake_vertices9, lake_vertices10]
labels = ['Advance', None, None, None,None,None,None,None,None,None,None]

plot_of_polygons(vertices_list, labels=labels)
# Out:
# <ipython-input-13-3f25eb80608e>:6: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   return patches.Polygon(vertices, closed=True, fill=True, edgecolor='none', color=color, label=label)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as patches

def crear_figuras(vertices, color='orange', label=None):
    """Creates a polygon patch from the given vertices."""
    return patches.Polygon(vertices, closed=True, fill=True, edgecolor='none', color=color)
def plot_of_polygons_with_cities(vertices_list, city_names, figsize=(12.8, 9.6),additional_texts1=None):
    """Generates a plot with polygons created from a list of vertices, and displays city labels."""
    fig, ax = plt.subplots(figsize=figsize)

    for vertices, city_name in zip(vertices_list, city_names):
        polygon = crear_figuras(vertices)
        ax.add_patch(polygon)

        # Calculate the centroid of the polygon
        centroid_x = sum(v[0] for v in vertices) / len(vertices)
        centroid_y = sum(v[1] for v in vertices) / len(vertices)

        ax.annotate(text=city_name,
            xy=(centroid_x, centroid_y),
            xytext=(10, -10), textcoords='offset points', ha='center', va='center', fontsize=8, color='black')
    if labels:
        plt.legend(loc='upper left')

    ax.set_xlim(0, 10)  # Adjusted for lake's shifted coordinates
    ax.set_ylim(0, 6)

    if additional_texts1 is not None:
        for text, x, y in additional_texts1:
            ax.annotate(text, xy=(x, y), xytext=(10, -10), textcoords='offset points',
                        ha='center', va='center', fontsize=8, color='black')
    ax.set_xlim(0, 10)  # Adjusted for lake's shifted coordinates

    plt.show()
labels = ['Advance', None, None, None,None,None,None,None,None,None,None]
city_names = ['Knowno',' ', 'Wilno',' ','','','Vitebisk', ' ', 'Dorogobuzh', 'Gagarin', '']
additional_texts1 = [('422,000', 1.1, 3.5), ('Mozhaysk', 8.06,4), ('Bobr', 4,2.1), ('´Polostk', 3.853,4)]

plot_of_polygons_with_cities(vertices_list, city_names, figsize=(12.8, 9.6),additional_texts1=additional_texts1)
# Out:
# <ipython-input-14-e417d2ccf2ef>:7: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   return patches.Polygon(vertices, closed=True, fill=True, edgecolor='none', color=color)
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

def crear_figuras(vertices, color='grey', label=None):
    """Creates a polygon patch from the given vertices."""
    return patches.Polygon(vertices, closed=True, fill=True, edgecolor='none', color=color, label=label)

def crear_figuras2(vertices, color='orange', label=None):
    """Creates a second type of polygon patch from the given vertices."""
    return patches.Polygon(vertices, closed=True, fill=True, edgecolor='none', color=color, label=label)


# Define the vertices of the polygons
# ...

# Add the vertices for both sets of polygons here
# ...
def plot_of_polygons(vertices_list, vertices_list2, labels=None, labels2=None, figsize=(12.8, 9.6), title=None, scale_factor=1.5):
    """Generates a plot with polygons created from two lists of vertices."""
    plt.style.use('default')
    fig, ax = plt.subplots(figsize=figsize)

    # Ensure labels lists are long enough
    while len(labels) < len(vertices_list):
        labels.append(None)
    while len(labels2) < len(vertices_list2):
        labels2.append(None)

    # Combine all vertices
    all_vertices = vertices_list + vertices_list2

    # Calculate maximum x and y values (for setting plot limits later)
    max_x = max(vertex[0] for polygon in all_vertices for vertex in polygon)
    max_y = max(vertex[1] for polygon in all_vertices for vertex in polygon)

    # Plot polygons from the first set
    for i, vertices in enumerate(vertices_list):
        # Apply the scale factor to the coordinates of the vertices
        scaled_vertices = [(x*scale_factor, y*scale_factor) for x, y in vertices]
        label = labels[i] if labels else None
        polygon = crear_figuras(scaled_vertices, label=label)
        ax.add_patch(polygon)

    # Plot polygons from the second set
    for i, vertices in enumerate(vertices_list2):
        # Apply the scale factor to the coordinates of the vertices
        scaled_vertices = [(x*scale_factor, y*scale_factor) for x, y in vertices]
        label = labels2[i] if labels2 else None
        polygon = crear_figuras2(scaled_vertices, label=label)
        ax.add_patch(polygon)

    # Set the limits of the plot to fit the scaled polygons
    ax.set_xlim(1, max_x * scale_factor)
    ax.set_ylim(2, max_y * scale_factor)

    ax.legend(loc='upper left')
    ax.set_title(title, fontdict={'fontsize': 13, 'color': 'black', 'fontname': 'serif'})


    return fig, ax




# Define the vertices of the polygons
# ...
# Add the vertices for both sets of polygons here
# ...

fig, ax = plot_of_polygons(vertices_list=vertices_list, vertices_list2=vertices_list2, labels=labels, labels2=labels2,title= "Charles Minard graph of Napoleon's Russian campaign of 1812")
fig.savefig('Minard.jpg')
# Out:
# <ipython-input-15-9a0981655b9d>:6: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   return patches.Polygon(vertices, closed=True, fill=True, edgecolor='none', color=color, label=label)
# <ipython-input-15-9a0981655b9d>:10: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   return patches.Polygon(vertices, closed=True, fill=True, edgecolor='none', color=color, label=label)

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

def crear_figuras(vertices, color='lightblue', label=None):
    """Creates a polygon patch from the given vertices."""
    return patches.Polygon(vertices, closed=True, fill=True, edgecolor='none', color=color, label=label)

def plot_of_polygons_with_multiple_cities(multiple_vertices, multiple_city_names, figsize=(12.8, 9.6), additional_texts=None):
    """Generates a plot with polygons created from a list of vertices, and displays city labels."""
    fig, ax = plt.subplots(figsize=figsize)

    for vertices_list, city_names in zip(multiple_vertices, multiple_city_names):
        for vertices, city_name in zip(vertices_list, city_names):
            polygon = crear_figuras(vertices)
            ax.add_patch(polygon)

            # Calculate the centroid of the polygon
            centroid_x = sum(v[0] for v in vertices) / len(vertices)
            centroid_y = sum(v[1] for v in vertices) / len(vertices)

            ax.annotate(text=city_name,
                xy=(centroid_x, centroid_y),
                xytext=(10, -10), textcoords='offset points', ha='center', va='center', fontsize=8, color='black')

    if additional_texts is not None:
        for text, x, y in additional_texts:
            ax.annotate(text, xy=(x, y), xytext=(10, -10), textcoords='offset points',
                        ha='center', va='center', fontsize=8, color='black')

    ax.set_xlim(0, 10)  # Adjusted for lake's shifted coordinates
    ax.set_ylim(0, 6)

    plt.show()

# Combine lists
multiple_vertices = [vertices_list, vertices_list2]
multiple_city_names = [city_names, city_names2]


plot_of_polygons_with_multiple_cities(multiple_vertices, multiple_city_names, figsize=(12.8, 9.6), additional_texts=additional_texts)
# Out:
# <ipython-input-16-ea79ee67f097>:6: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   return patches.Polygon(vertices, closed=True, fill=True, edgecolor='none', color=color, label=label)

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

def crear_figuras(vertices, color='lightblue', label=None):
    """Creates a polygon patch from the given vertices."""
    return patches.Polygon(vertices, closed=True, fill=True, edgecolor='none', color=color, label=label)

def plot_of_polygons_with_multiple_cities(multiple_vertices, multiple_city_names, figsize=(12.8, 9.6), additional_texts=None,additional_texts1=None, title=None):
    """Generates a plot with polygons created from a list of vertices, and displays city labels."""
    fig, ax = plt.subplots(figsize=figsize)

    colors = ['lightblue', 'orange']  # Colors for the patches
    labels = [
        ['Advance', None, None, None, None, None, None, None, None, None, None],
        ['Retreat', None, None, None, None, None, None, None, None, None, None, None, None, None, None]
    ]  # Labels for the patches

    for i, (vertices_list, city_names) in enumerate(zip(multiple_vertices, multiple_city_names)):
        for vertices, city_name, label in zip(vertices_list, city_names, labels[i]):
            polygon = crear_figuras(vertices, color=colors[i], label=label)
            ax.add_patch(polygon)

            # Calculate the centroid of the polygon
            centroid_x = sum(v[0] for v in vertices) / len(vertices)
            centroid_y = sum(v[1] for v in vertices) / len(vertices)

            ax.annotate(text=city_name,
                xy=(centroid_x, centroid_y),
                xytext=(10, -10), textcoords='offset points', ha='center', va='center', fontsize=8, color='black')

    if additional_texts is not None:
        for text, x, y in additional_texts:
            ax.annotate(text, xy=(x, y), xytext=(10, -10), textcoords='offset points',
                        ha='center', va='center', fontsize=8, color='black')
    if additional_texts1 is not None:
        for text, x, y in additional_texts1:
            ax.annotate(text, xy=(x, y), xytext=(10, -10), textcoords='offset points',
                        ha='center', va='center', fontsize=8, color='black')

    arrow1 = plt.arrow(2, 1, 1, 3, color='red', width=0.005, head_width=0.05, head_length=0.05)
    arrow2 = plt.arrow(2, 1, 1, 2, color='blue', width=0.005, head_width=0.05, head_length=0.05)
    ax.set_xlim(0, 10)  # Adjusted for lake's shifted coordinates
    ax.set_ylim(0, 6)
    ax.legend(loc='upper left')
    ax.set_title(title, fontdict={'fontsize': 13, 'color': 'black', 'fontname': 'serif'})
    plt.show()

# Combine lists
multiple_vertices = [vertices_list, vertices_list2]
multiple_city_names = [city_names, city_names2]

plot_of_polygons_with_multiple_cities(multiple_vertices, multiple_city_names, figsize=(12.8, 9.6), additional_texts=additional_texts, additional_texts1=additional_texts1,title="Charles Minard graph of Napoleon's Russian campaign of 1812")
# Out:
# <ipython-input-17-1c5e0c0e6986>:6: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   return patches.Polygon(vertices, closed=True, fill=True, edgecolor='none', color=color, label=label)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Reading in the data and selecting the temperature data
data = pd.read_csv('Minard.csv')
temperatures = data[["LONT", "TEMP", "DAYS", "MON", "DAY", "TEMPP"]].dropna()

# Create the plot for temperature
fig, ax = plt.subplots(figsize=(13, 2.9))

# Plot temperature during retreat (Line chart)
sns.lineplot(data=temperatures, x='LONT', y='TEMP', color='#d6a529', ax=ax, linewidth=2, label='Temperature during retreat')

# Calculate the mean temperature
mean_temp = temperatures['TEMP'].mean()

# Add a parallel line at the mean temperature
sns.lineplot(data=temperatures, x='LONT', y='TEMPP', color='#5891a7', ax=ax, linewidth=2, label='Mean temperature')

ax.set_ylabel("Temperature [°C]")
ax.set_xlabel("Dates of the Russian Campaign of 1812")
ax.grid(True)

# Remove the borders of the chart
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)

# Show the legend
ax.legend()

# Show the temperature chart
plt.xticks(ticks=temperatures['LONT'], labels=[f"{row['MON']} {row['DAY']} {row['TEMP']}" for _, row in temperatures.iterrows()], rotation=45)

# Adjust spacing
plt.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

def crear_figuras(vertices, color='lightblue', label=None):
    """Creates a polygon patch from the given vertices."""
    return patches.Polygon(vertices, closed=True, fill=True, edgecolor='none', color=color, label=label)

def plot_of_polygons_with_multiple_cities(multiple_vertices, multiple_city_names, figsize=(12.8, 9.6), additional_texts=None,additional_texts1=None, title=None):
    """Generates a plot with polygons created from a list of vertices, and displays city labels."""
    fig = plt.figure(figsize=figsize)
    gs = fig.add_gridspec(2, 1, height_ratios=[2.5, 1])

    # Create the subplots
    ax0 = fig.add_subplot(gs[0])
    ax1 = fig.add_subplot(gs[1])

    max_x_global = max(vertex[0] for vertices_list in multiple_vertices for vertex in vertices_list)
    max_y_global = max(vertex[1] for vertices_list in multiple_vertices for vertex in vertices_list)


    colors = ['gray', 'orange']  # Colors for the patches
    labels = [
        ['Advance', None, None, None, None, None, None, None, None, None, None],
        ['Retreat', None, None, None, None, None, None, None, None, None, None, None, None, None, None]
    ]  # Labels for the patches

    for i, (vertices_list, city_names) in enumerate(zip(multiple_vertices, multiple_city_names)):
        for vertices, city_name, label in zip(vertices_list, city_names, labels[i]):
            polygon = crear_figuras(vertices, color=colors[i], label=label)
            ax0.add_patch(polygon)

            # Calculate the centroid of the polygon
            centroid_x = sum(v[0] for v in vertices) / len(vertices)
            centroid_y = sum(v[1] for v in vertices) / len(vertices)

            ax0.annotate(text=city_name,
                xy=(centroid_x, centroid_y),
                xytext=(10, -10), textcoords='offset points', ha='center', va='center', fontsize=8, color='black')

    if additional_texts is not None:
        for text, x, y in additional_texts:
            ax0.annotate(text, xy=(x, y), xytext=(10, -10), textcoords='offset points',
                        ha='center', va='center', fontsize=8, color='black')
    if additional_texts1 is not None:
        for text, x, y in additional_texts1:
            ax0.annotate(text, xy=(x, y), xytext=(10, -10), textcoords='offset points',
                        ha='center', va='center', fontsize=8, color='black')

    #arrow1 = plt.arrow(2, 1, 1, 3, color='red', width=0.005, head_width=0.05, head_length=0.05)
    #arrow2 = plt.arrow(2, 1, 1, 2, color='blue', width=0.005, head_width=0.05, head_length=0.05)
    ax0.set_xlim(1, 9.19)  # Adjusted for lake's shifted coordinates
    ax0.set_ylim(1.869, 5.146)
    ax0.legend(loc='upper left')
    ax0.set_title(title, fontdict={'fontsize': 13, 'color': 'black', 'fontname': 'serif'})
    ax0.axis('off')
 # Reading in the data and selecting the temperature data
    data = pd.read_csv('Minard.csv')
    temperatures = data[["LONT", "TEMP", "DAYS", "MON", "DAY", "TEMPP"]].dropna()

    # Plot temperature during retreat (Line chart) in the second subplot
    sns.lineplot(data=temperatures, x='LONT', y='TEMP', color='#d6a529', ax=ax1, linewidth=2)

    # Calculate the mean temperature
    mean_temp = temperatures['TEMP'].mean()

    # Add a parallel line at the mean temperature
    sns.lineplot(data=temperatures, x='LONT', y='TEMPP', color='#5891a7', ax=ax1, linewidth=2)


    ax1.set_ylabel("Temperature [°C]", labelpad=50, fontsize=15)
    ax1.set_xlabel("Dates of the Russian Campaign of 1812")
    ax1.grid(True)



    # Remove the borders of the chart
    ax1.spines['top'].set_visible(False)
    ax1.spines['right'].set_visible(False)
    ax1.spines['bottom'].set_visible(False)
    ax1.spines['left'].set_visible(False)
     # Show the temperature chart
    plt.xticks(ticks=temperatures['LONT'], labels=[f"{row['MON']} {row['DAY']} {row['TEMP']}" for _, row in temperatures.iterrows()], rotation=45)

    # Adjust spacing
    plt.tight_layout()

    return fig, (ax1,ax0)

# Combine lists
multiple_vertices = [vertices_list, vertices_list2]
multiple_city_names = [city_names, city_names2]

fig, (ax0, ax1)=plot_of_polygons_with_multiple_cities(multiple_vertices, multiple_city_names, figsize=(10,6), additional_texts=additional_texts, additional_texts1=additional_texts1,title="Charles Minard graph of Napoleon's Russian campaign of 1812")
plt.show()
# Out:
# <ipython-input-19-2e62ade87d86>:6: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   return patches.Polygon(vertices, closed=True, fill=True, edgecolor='none', color=color, label=label)

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

def crear_figuras(vertices, color='orange', label=None):
    """Creates a polygon patch from the given vertices."""
    return patches.Polygon(vertices, closed=True, fill=True, edgecolor='none', color=color, label=label)

def scale_and_shift_vertices(multiple_vertices, scale_factor=1, shift_x=0, shift_y=0):
    """Scales and shifts vertices by given factors."""
    return [[[(x*scale_factor)+shift_x, (y*scale_factor)+shift_y] for x, y in vertices] for vertices in multiple_vertices]

def plot_of_polygons_with_multiple_cities(multiple_vertices, multiple_city_names, scale_factor=1, shift_x=3, shift_y=0, figsize=(13, 2), additional_texts=None,additional_texts1=None,additional_texts2=None,title=None):
    """Generates a plot with polygons created from a list of vertices, and displays city labels."""
    fig = plt.figure(figsize=figsize)
    gs = fig.add_gridspec(2, 1, height_ratios=[2.5, 1])

    # Create the subplots
    ax0 = fig.add_subplot(gs[0])
    ax1 = fig.add_subplot(gs[1])

    max_x_global = max(vertex[0] for vertices_list in multiple_vertices for vertex in vertices_list)
    max_y_global = max(vertex[1] for vertices_list in multiple_vertices for vertex in vertices_list)


    colors = ["#008080", 'orange']  # Colors for the patches
    labels = [
        ['Advance', None, None, None, None, None, None, None, None, None, None],
        ['Retreat', None, None, None, None, None, None, None, None, None, None, None, None, None, None]
    ]  # Labels for the patches

    for i, (vertices_list, city_names) in enumerate(zip(multiple_vertices, multiple_city_names)):
        for vertices, city_name, label in zip(vertices_list, city_names, labels[i]):
            polygon = crear_figuras(vertices, color=colors[i], label=label)
            ax0.add_patch(polygon)

            # Calculate the centroid of the polygon
            centroid_x = sum(v[0] for v in vertices) / len(vertices)
            centroid_y = sum(v[1] for v in vertices) / len(vertices)

            ax0.annotate(text=city_name,
                xy=(centroid_x, centroid_y),
                xytext=(10, -10), textcoords='offset points', ha='center', va='center', fontsize=10, color='black')

    if additional_texts is not None:
        for text, x, y in additional_texts:
            ax0.annotate(text, xy=(x, y), xytext=(10, -10), textcoords='offset points',
                        ha='center', va='center', fontsize=10, color='black')
    if additional_texts1 is not None:
        for text, x, y in additional_texts1:
            ax0.annotate(text, xy=(x, y), xytext=(10, -10), textcoords='offset points',
                        ha='center', va='center', fontsize=10, color="#008080")


    if additional_texts2 is not None:
        for text, x, y in additional_texts2:
            ax0.annotate(text, xy=(x, y), xytext=(10, -10), textcoords='offset points',
                        ha='center', va='center', fontsize=10, color="orange")


    arrow1 = patches.FancyArrow(1 , 1 , 2, 3, color='red', width=0.005,head_width=0.05, head_length=0.08, shape='full')
    arrow2 = patches.FancyArrow(1 ,1 , 1, 2, color='blue', width=0.005,head_width=0.05, head_length=0.08, shape='full')
    #FancyArrow(x, y, dx, dy, width=0.001, length_includes_head=False, head_width=None, head_length=None, shape='full', overhang=0, head_starts_at_zero=False, **kwargs)
    ax0.add_patch(arrow1)
    ax0.add_patch(arrow2)

    ax0.set_xlim(1, 9.19)  # Adjusted for lake's shifted coordinates
    ax0.set_ylim(1.869, 5.146)
    ax0.legend(loc='upper left')
    ax0.set_title(title, fontdict={'fontsize': 13, 'color': 'red', 'fontname': 'serif'})
    ax0.axis('off')
 # Reading in the data and selecting the temperature data
    data = pd.read_csv('Minard.csv')
    temperatures = data[["LONT", "TEMP", "DAYS", "MON", "DAY", "TEMPP"]].dropna()

    # Plot temperature during retreat (Line chart) in the second subplot
    sns.lineplot(data=temperatures, x='LONT', y='TEMP', color='#d6a529', ax=ax1, linewidth=2)

    # Calculate the mean temperature
    mean_temp = temperatures['TEMP'].mean()

    # Add a parallel line at the mean temperature
    sns.lineplot(data=temperatures, x='LONT', y='TEMPP', color='#5891a7', ax=ax1, linewidth=2)


    ax1.set_ylabel("Temperature [°C]", labelpad=50, fontsize=15)
    ax1.set_xlabel("Dates of the Russian Campaign of 1812")
    ax1.grid(True)



    # Remove the borders of the chart
    ax1.spines['top'].set_visible(False)
    ax1.spines['right'].set_visible(False)
    ax1.spines['bottom'].set_visible(False)
    ax1.spines['left'].set_visible(False)
     # Show the temperature chart
    plt.xticks(ticks=temperatures['LONT'], labels=[f"{row['MON']} {row['DAY']} {row['TEMP']}" for _, row in temperatures.iterrows()], rotation=45)

    # Adjust spacing
    plt.tight_layout()

    return fig, (ax1,ax0)
additional_texts1 = [('422,000', 1.1, 3.6), ('22,000', 1.2,4.2) ,('400,000', 2,3.55), ('60,000', 3,3.7),('175,000', 5.2,3.7),
                     ('145,000', 5.8,3.6), ('127,100', 7.9,4.8),('100,000', 8.4,5.1), ('33,000', 3,4.31)]

additional_texts2= [('10,000', 1, 2.2), ('6,000', 2,4.2) ,('4,000',1.7,2.2), ('8,000', 2.2,2.2),('28,000', 3.2,2.55),
                     ('12,500', 2.8,2.1), ('50,000', 3.1,1.9),('20,000', 4.1,2.5), ('33,000', 3,4.31)]
# Combine lists
multiple_vertices = [vertices_list, vertices_list2]
multiple_city_names = [city_names, city_names2]
scale_factor = 1
shift_x = 1
shift_y = 0
fig, (ax0, ax1)=plot_of_polygons_with_multiple_cities(multiple_vertices, multiple_city_names, scale_factor, shift_x, shift_y, figsize=(10, 6), additional_texts=additional_texts, additional_texts1=additional_texts1,additional_texts2=additional_texts2,title= "Charles Minard graph of Napoleon's Russian campaign of 1812")
#fig.savefig('Minardios.jpg')
plt.show()
# Out:
# <ipython-input-20-70f78e307c8b>:6: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   return patches.Polygon(vertices, closed=True, fill=True, edgecolor='none', color=color, label=label)

# %%
print(multiple_vertices)
# Out:
# [[[(1.2, 2.23), (1.75, 2.41), (1.75, 3.4), (1, 3.2)], [(1.75, 2.41), (1.8, 2.41), (1.8, 4.18), (1.7, 4.18)], [(1.8, 2.41), (2.51, 2.24), (2.51, 3.08), (1.8, 3.3)], [(2.348, 3.11), (2.46, 3.065), (2.9335, 3.791), (2.8765, 3.9875)], [(2.9335, 3.791), (3.748, 3.82), (3.803, 3.9258), (2.8765, 3.9875)], [(2.51, 2.24), (4.656, 3.056), (4.656, 3.615), (2.51, 3.08)], [(4.656, 3.056), (5.8, 2.667), (5.775, 3.115), (4.656, 3.615)], [(5.8, 2.667), (6.65, 3.23), (6.609, 3.621), (5.775, 3.115)], [(6.65, 3.23), (7.714, 4.252), (7.657, 4.576), (6.609, 3.621)], [(7.714, 4.252), (8.454, 4.1021), (8.447, 4.348), (7.657, 4.576)], [(8.454, 4.1021), (9.19, 4.945), (9.128, 5.146), (8.447, 4.348)]], [[(1.24, 2.2), (1.8568, 2.19), (1.8568, 2.22), (1.24, 2.22)], [(1.8568, 2.2), (1.8, 2.2), (1.8, 4.18), (1.8, 4.18)], [(1.832, 2.2), (2.7541, 2.0983), (2.7541, 2.1648), (1.85668, 2.24)], [(2.775, 2.0983), (3.0935, 2.25), (3.0935, 2.34), (2.752, 2.1648)], [(3.0935, 2.25), (3.5, 1.869), (3.5, 1.987), (3.0935, 2.34
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

def crear_figuras(vertices, color='orange', label=None):
    """Creates a polygon patch from the given vertices."""
    return patches.Polygon(vertices, closed=True, fill=True, edgecolor='none', color=color, label=label)

def scale_and_shift_vertices(multiple_vertices, scale_factor=1, shift_x=0, shift_y=0):
    """Scales and shifts vertices by given factors."""
    return [[[[(x*scale_factor)+shift_x, (y*scale_factor)+shift_y] for x, y in polygon] for polygon in city] for city in multiple_vertices]


def plot_of_polygons_with_multiple_cities(multiple_vertices, multiple_city_names, scale_factor=1,
                                       shift_x=3, shift_y=0, figsize=(13, 2),
                                       additional_texts=None,additional_texts1=None,additional_texts2=None,
                                       additional_texts3=None,title=None):
    """Generates a plot with polygons created from a list of vertices, and displays city labels."""

    multiple_vertices = scale_and_shift_vertices(multiple_vertices, scale_factor, shift_x, shift_y)
    fig = plt.figure(figsize=figsize)
    gs = fig.add_gridspec(2, 1, height_ratios=[2.5, 1])

    # Create the subplots
    ax0 = fig.add_subplot(gs[0])
    ax1 = fig.add_subplot(gs[1])


    ax = fig.add_subplot(111, frame_on=False)
    plt.tick_params(labelcolor='none', top=False, bottom=False, left=False, right=False)
    ax.set_xticks([])
    ax.set_yticks([])


    max_x_global = max(vertex[0] for vertices_list in multiple_vertices for vertex in vertices_list)
    max_y_global = max(vertex[1] for vertices_list in multiple_vertices for vertex in vertices_list)


    colors = ["#008080", 'orange']  # Colors for the patches
    labels = [
        ['Advance', None, None, None, None, None, None, None, None, None, None],
        ['Retreat', None, None, None, None, None, None, None, None, None, None, None, None, None, None]
    ]  # Labels for the patches

    for i, (vertices_list, city_names) in enumerate(zip(multiple_vertices, multiple_city_names)):
        for vertices, city_name, label in zip(vertices_list, city_names, labels[i]):
            polygon = crear_figuras(vertices, color=colors[i], label=label)
            ax0.add_patch(polygon)

            # Calculate the centroid of the polygon
            centroid_x = sum(v[0] for v in vertices) / len(vertices)
            centroid_y = sum(v[1] for v in vertices) / len(vertices)

            ax0.annotate(text=city_name,
                xy=(centroid_x, centroid_y),
                xytext=(10, -10), textcoords='offset points', ha='center', va='center', fontsize=10, color='black')

    if additional_texts is not None:
        for text, x, y in additional_texts:
            ax0.annotate(text, xy=(x, y), xytext=(10, -10), textcoords='offset points',
                        ha='center', va='center', fontsize=10, color='black')
    if additional_texts1 is not None:
        for text, x, y in additional_texts1:
            ax0.annotate(text, xy=(x, y), xytext=(10, -10), textcoords='offset points',
                        ha='center', va='center', fontsize=10, color="#008080")


    if additional_texts2 is not None:
        for text, x, y in additional_texts2:
            ax0.annotate(text, xy=(x, y), xytext=(10, -10), textcoords='offset points',
                        ha='center', va='center', fontsize=10, color="orange")


    if additional_texts3 is not None:
        for text, x, y in additional_texts3:
            ax0.annotate(text, xy=(x, y), xytext=(10, -10), textcoords='offset points',
                        ha='center', va='center', fontsize=10, color="black")


    start_x = 4.2
    start_y = 4.75

    end_x1 = 3.853
    end_y1 = 4.2

    end_x2 = 3.1
    end_y2 = 4.31

    # Calculate displacements
    dx1 = end_x1 - start_x
    dy1 = end_y1 - start_y

    dx2 = end_x2 - start_x
    dy2 = end_y2 - start_y

    arrow1 = patches.FancyArrow(start_x, start_y, dx1, dy1, color='orange', width=0.005,head_width=0.05, head_length=0.08, shape='full')
    arrow2 = patches.FancyArrow(start_x, start_y, dx2, dy2, color="#008080", width=0.005,head_width=0.05, head_length=0.08, shape='full')

    ax0.add_patch(arrow1)
    ax0.add_patch(arrow2)

    ax0.set_xlim(1, 9.19)  # Adjusted for lake's shifted coordinates
    ax0.set_ylim(1.869, 5.146)
    ax0.legend(loc='upper left')
    ax0.set_title(title, fontdict={'fontsize': 13, 'color': 'red', 'fontname': 'serif'})
    ax0.axis('off')
 # Reading in the data and selecting the temperature data
    data = pd.read_csv('Minard.csv')
    temperatures = data[["LONT", "TEMP", "DAYS", "MON", "DAY", "TEMPP"]].dropna()

    # Plot temperature during retreat (Line chart) in the second subplot

    sns.lineplot(data=temperatures, x='LONT', y='TEMP', color="#008080", ax=ax1, linewidth=2,label='Advance Temperature')

    # Calculate the mean temperature
    mean_temp = temperatures['TEMP'].mean()

    # Add a parallel line at the mean temperature


    sns.lineplot(data=temperatures, x='LONT', y='TEMPP', color="orange", ax=ax1, linewidth=2, label= 'Retreat Temperature')


    ax1.set_ylabel("Temperature [°C]", labelpad=50, fontsize=15)
    ax1.set_xlabel("Dates of the Russian Campaign of 1812")
    ax1.grid(True)


    # Remove the borders of the chart
    ax1.spines['top'].set_visible(False)
    ax1.spines['right'].set_visible(False)
    ax1.spines['bottom'].set_visible(False)
    ax1.spines['left'].set_visible(False)

     # Show the temperature chart
    plt.xticks(ticks=temperatures['LONT'], labels=[f"{row['MON']} {row['DAY']} {row['TEMP']}" for _, row in temperatures.iterrows()], rotation=45)

    print(plt.xticks(ticks=temperatures['LONT'], labels=[f"{row['MON']} {row['DAY']} {row['TEMP']}" for _, row in temperatures.iterrows()], rotation=45))

    start_points = [(1.8, 1.8), (3, 1.8), (4.2, 1.8), (5.4,1.8), (6.65, 1.8), (7.85, 1.8), (9.05, 0)]
    end_points = [(1.8, 2.5), (3, 2.3), (4.2, 2.2), (5.4,2.5), (6.65,2.8),  (7.85, 3.6), (9.05,3.6)]


    # Plot each line
    for start, end in zip(start_points, end_points):
        ax0.plot([start[0], end[0]], [start[1], end[1]], color='red', linestyle='--', linewidth=2)



    return fig, (ax1,ax0)
additional_texts1 = [('422,000', 1.1, 3.6), ('22,000', 1.2,4.2) ,('400,000', 2,3.55), ('60,000', 3,3.7),('175,000', 5.2,3.7),
                     ('145,000', 5.8,3.6), ('127,100', 7.9,4.8),('100,000', 8.4,5.1), ('33,000', 3,4.31)]

additional_texts2= [('10,000', 1, 2.2), ('6,000', 2,4.2) ,('4,000',1.7,2.2), ('8,000', 2.2,2.2),('28,000', 3.2,2.55),
                     ('12,500', 2.8,2.1), ('50,000', 3.1,1.9),('20,000', 4.1,2.5), ('24,000', 5.5,2.31) ,
                     ('37,000', 6.3,2.5), ('55,000', 7,3),('87,000', 7.7,3.48), ('96,000', 8.5,3.35),
                     ('100,000', 8.4,4.95), ('30,000',3.853,4.2)]


additional_texts3= [('Number of \n soldiers',4.45,4.75)]

# Combine lists
multiple_vertices = [vertices_list, vertices_list2]
multiple_city_names = [city_names, city_names2]
scale_factor = 1
shift_x = 0
shift_y = 0
fig, (ax0, ax1)=plot_of_polygons_with_multiple_cities(multiple_vertices, multiple_city_names, scale_factor, shift_x, shift_y, figsize=(10, 6), additional_texts=additional_texts, additional_texts1=additional_texts1,additional_texts2=additional_texts2,additional_texts3=additional_texts3,title= "Charles Minard graph of Napoleon's Russian campaign of 1812")
fig.savefig('Minardinho.jpg')
plt.show()
# Out:
# <ipython-input-50-c8aad503c3c1>:6: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   return patches.Polygon(vertices, closed=True, fill=True, edgecolor='none', color=color, label=label)
# ([<matplotlib.axis.XTick object at 0x7b04096cea40>, <matplotlib.axis.XTick object at 0x7b04096cd3f0>, <matplotlib.axis.XTick object at 0x7b04090efdc0>, <matplotlib.axis.XTick object at 0x7b040b9723b0>, <matplotlib.axis.XTick object at 0x7b040b973a60>, <matplotlib.axis.XTick object at 0x7b040b9709d0>, <matplotlib.axis.XTick object at 0x7b0409857fd0>, <matplotlib.axis.XTick object at 0x7b040b981cc0>], [Text(37.6, 0, 'Oct 18.0 0.0'), Text(36.0, 0, 'Oct 24.0 0.0'), Text(33.2, 0, 'Nov 9.0 -9.0'), Text(32.0, 0, 'Nov 14.0 -21.0'), Text(28.5, 0, 'Nov 28.0 -20.0'), Text(27.2, 0, 'Dec 1.0 -24.0'), Text(26.7, 0, 'Dec 6.0 -30.0'), Text(25.3, 0, 'Dec 7.0 -26.0')])

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

def crear_figuras(vertices, color='orange', label=None):
    """Creates a polygon patch from the given vertices."""
    return patches.Polygon(vertices, closed=True, fill=True, edgecolor='none', color=color, label=label)

def scale_and_shift_vertices(multiple_vertices, scale_factor=1, shift_x=0, shift_y=0):
    """Scales and shifts vertices by given factors."""
    return [[[[(x*scale_factor)+shift_x, (y*scale_factor)+shift_y] for x, y in polygon] for polygon in city] for city in multiple_vertices]


def plot_of_polygons_with_multiple_cities(multiple_vertices, multiple_city_names, scale_factor=1,
                                       shift_x=3, shift_y=0, figsize=(13, 2),
                                       additional_texts=None,additional_texts1=None,additional_texts2=None,
                                       additional_texts3=None,title=None):
    """Generates a plot with polygons created from a list of vertices, and displays city labels."""

    multiple_vertices = scale_and_shift_vertices(multiple_vertices, scale_factor, shift_x, shift_y)
    fig = plt.figure(figsize=figsize)
    gs = fig.add_gridspec(2, 1, height_ratios=[2.5, 1])

    # Create the subplots
    ax0 = fig.add_subplot(gs[0])
    ax1 = fig.add_subplot(gs[1])


    ax = fig.add_subplot(111, frame_on=False)
    plt.tick_params(labelcolor='none', top=False, bottom=False, left=False, right=False)
    ax.set_xticks([])
    ax.set_yticks([])


    max_x_global = max(vertex[0] for vertices_list in multiple_vertices for vertex in vertices_list)
    max_y_global = max(vertex[1] for vertices_list in multiple_vertices for vertex in vertices_list)


    colors = ["#008080", 'orange']  # Colors for the patches
    labels = [
        ['Advance', None, None, None, None, None, None, None, None, None, None],
        ['Retreat', None, None, None, None, None, None, None, None, None, None, None, None, None, None]
    ]  # Labels for the patches

    for i, (vertices_list, city_names) in enumerate(zip(multiple_vertices, multiple_city_names)):
        for vertices, city_name, label in zip(vertices_list, city_names, labels[i]):
            polygon = crear_figuras(vertices, color=colors[i], label=label)
            ax0.add_patch(polygon)

            # Calculate the centroid of the polygon
            centroid_x = sum(v[0] for v in vertices) / len(vertices)
            centroid_y = sum(v[1] for v in vertices) / len(vertices)

            ax0.annotate(text=city_name,
                xy=(centroid_x, centroid_y),
                xytext=(10, -10), textcoords='offset points', ha='center', va='center', fontsize=10, color='black')

    if additional_texts is not None:
        for text, x, y in additional_texts:
            ax0.annotate(text, xy=(x, y), xytext=(10, -10), textcoords='offset points',
                        ha='center', va='center', fontsize=10, color='black')
    if additional_texts1 is not None:
        for text, x, y in additional_texts1:
            ax0.annotate(text, xy=(x, y), xytext=(10, -10), textcoords='offset points',
                        ha='center', va='center', fontsize=10, color="#008080")


    if additional_texts2 is not None:
        for text, x, y in additional_texts2:
            ax0.annotate(text, xy=(x, y), xytext=(10, -10), textcoords='offset points',
                        ha='center', va='center', fontsize=10, color="orange")


    if additional_texts3 is not None:
        for text, x, y in additional_texts3:
            ax0.annotate(text, xy=(x, y), xytext=(10, -10), textcoords='offset points',
                        ha='center', va='center', fontsize=10, color="black")


    start_x = 4.2
    start_y = 4.75

    end_x1 = 3.853
    end_y1 = 4.2

    end_x2 = 3.1
    end_y2 = 4.31

    # Calculate displacements
    dx1 = end_x1 - start_x
    dy1 = end_y1 - start_y

    dx2 = end_x2 - start_x
    dy2 = end_y2 - start_y

    arrow1 = patches.FancyArrow(start_x, start_y, dx1, dy1, color='orange', width=0.005,head_width=0.05, head_length=0.08, shape='full')
    arrow2 = patches.FancyArrow(start_x, start_y, dx2, dy2, color="#008080", width=0.005,head_width=0.05, head_length=0.08, shape='full')

    ax0.add_patch(arrow1)
    ax0.add_patch(arrow2)

    ax0.set_xlim(1, 9.19)  # Adjusted for lake's shifted coordinates
    ax0.set_ylim(1.869, 5.146)
    ax0.legend(loc='upper left')
    ax0.set_title(title, fontdict={'fontsize': 13, 'color': 'red', 'fontname': 'serif'})
    ax0.axis('off')
 # Reading in the data and selecting the temperature data
    data = pd.read_csv('Minard.csv')
    temperatures = data[["LONT", "TEMP", "DAYS", "MON", "DAY", "TEMPP"]].dropna()

    # Plot temperature during retreat (Line chart) in the second subplot

    sns.lineplot(data=temperatures, x='LONT', y='TEMP', color="#008080", ax=ax1, linewidth=2,label='Advance Temperature')

    # Calculate the mean temperature
    mean_temp = temperatures['TEMP'].mean()

    # Add a parallel line at the mean temperature


    sns.lineplot(data=temperatures, x='LONT', y='TEMPP', color="orange", ax=ax1, linewidth=2, label= 'Retreat Temperature')


    ax1.set_ylabel("Temperature [°C]", labelpad=50, fontsize=15)
    ax1.set_xlabel("Dates of the Russian Campaign of 1812")
    ax1.grid(True)


    # Remove the borders of the chart
    ax1.spines['top'].set_visible(False)
    ax1.spines['right'].set_visible(False)
    ax1.spines['bottom'].set_visible(False)
    ax1.spines['left'].set_visible(False)

     # Show the temperature chart
    # Set the x-ticks and x-tick labels
    ax1.set_xticks(temperatures['LONT'])
    ax1.set_xticklabels([f"{row['MON']} {row['DAY']} {row['TEMP']}" for _, row in temperatures.iterrows()], rotation=45, ha="right")


    print(plt.xticks(ticks=temperatures['LONT'], labels=[f"{row['MON']} {row['DAY']} {row['TEMP']}" for _, row in temperatures.iterrows()], rotation=45))

    start_points = [(1.8, 1.8), (3, 1.8), (4.2, 1.8), (5.4,1.8), (6.65, 1.8), (7.85, 1.8), (9.05, 0)]
    end_points = [(1.8, 2.5), (3, 2.3), (4.2, 2.2), (5.4,2.5), (6.65,2.8),  (7.85, 3.6), (9.05,3.6)]


    # Plot each line
    for start, end in zip(start_points, end_points):
        ax0.plot([start[0], end[0]], [start[1], end[1]], color='red', linestyle='--', linewidth=2)



    return fig, (ax1,ax0)
additional_texts1 = [('422,000', 1.1, 3.6), ('22,000', 1.2,4.2) ,('400,000', 2,3.55), ('60,000', 3,3.7),('175,000', 5.2,3.7),
                     ('145,000', 5.8,3.6), ('127,100', 7.9,4.8),('100,000', 8.4,5.1), ('33,000', 3,4.31)]

additional_texts2= [('10,000', 1, 2.2), ('6,000', 2,4.2) ,('4,000',1.7,2.2), ('8,000', 2.2,2.2),('28,000', 3.2,2.55),
                     ('12,500', 2.8,2.1), ('50,000', 3.1,1.9),('20,000', 4.1,2.5), ('24,000', 5.5,2.31) ,
                     ('37,000', 6.3,2.5), ('55,000', 7,3),('87,000', 7.7,3.48), ('96,000', 8.5,3.35),
                     ('100,000', 8.4,4.95), ('30,000',3.853,4.2)]


additional_texts3= [('Number of \n soldiers',4.45,4.75)]

# Combine lists
multiple_vertices = [vertices_list, vertices_list2]
multiple_city_names = [city_names, city_names2]
scale_factor = 1
shift_x = 0
shift_y = 0
fig, (ax0, ax1)=plot_of_polygons_with_multiple_cities(multiple_vertices, multiple_city_names, scale_factor, shift_x, shift_y, figsize=(10, 6), additional_texts=additional_texts, additional_texts1=additional_texts1,additional_texts2=additional_texts2,additional_texts3=additional_texts3,title= "Charles Minard graph of Napoleon's Russian campaign of 1812")
fig.savefig('Minardinho.jpg')
plt.show()
# Out:
# <ipython-input-49-bcab151eeabf>:6: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   return patches.Polygon(vertices, closed=True, fill=True, edgecolor='none', color=color, label=label)
# ([<matplotlib.axis.XTick object at 0x7b0409075de0>, <matplotlib.axis.XTick object at 0x7b04090754e0>, <matplotlib.axis.XTick object at 0x7b04090771c0>, <matplotlib.axis.XTick object at 0x7b040911d930>, <matplotlib.axis.XTick object at 0x7b040911f940>, <matplotlib.axis.XTick object at 0x7b040911dff0>, <matplotlib.axis.XTick object at 0x7b040911fb50>, <matplotlib.axis.XTick object at 0x7b040911e7d0>], [Text(37.6, 0, 'Oct 18.0 0.0'), Text(36.0, 0, 'Oct 24.0 0.0'), Text(33.2, 0, 'Nov 9.0 -9.0'), Text(32.0, 0, 'Nov 14.0 -21.0'), Text(28.5, 0, 'Nov 28.0 -20.0'), Text(27.2, 0, 'Dec 1.0 -24.0'), Text(26.7, 0, 'Dec 6.0 -30.0'), Text(25.3, 0, 'Dec 7.0 -26.0')])
